5049.63, 5661.78, 4363.02, 4732.27, 5103.42, 4904.25, 4407.75, 4597.27, 3481.85, 4653.04, 5110.77, 5831.02, 10231.17, 10707.18, 9035.27, 8612.44, 9957.61, 12180.53, 11897.11, 6763.46, 12052.84, 8626.89, 7817.11, 13698.09, 15807.85, 8120.53, 26765.78, 22276.6, 8687.81, 7878.94, 12154.73, 8628.68, 7738.95, 9425.64, 6709.65, 5698.2, 10423.3, 8629.03, 6955.69, 8028.75, 5515.91, 12933.97, 13106.29, 8771.79, 7749.4, 1279.48, 1143.57, 982.45, 1003.84, 1108.2, 978.29, 834.3, 1074.64, 1059.63, 1150.03, 1309.82, 1369.62, 1224.99, 1966.94, 1182.85, 891.6, 940.89, 2256.96, 2119.14, 1154.19, 1414.21, 1552.51, 2135.74, 3700.92, 4766.71, 3424.69, 3393.83, 2613.51, 2140.13, 3623.46, 2865.59, 3195.15, 4322.99, 4618.45, 4161.33, 5187.46, 3245.62, 5096.43, 8972.11, 3767.76, 3888.05, 3304.62, 3188.52, 2542.94, 3747.77, 3295.09, 3486.2, 2238.78, 3524.96, 6707.82, 8750.08, 8697.35, 4425.75, 1070.24, 1045.38, 1401.87, 1225.97, 1063.32, 1905.46, 1839.8, 1703.52, 1270.61, 1490.02, 1580.01, 1289.07]
}

avocados = pd.DataFrame(data)

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Look at the first few rows of data
print(avocados.head())

# Get the total number of avocados sold of each size
nb_sold_by_size = avocados.groupby("size")["nb_sold"].sum()
print(nb_sold_by_size)

chart = nb_sold_by_size.plot(x="nb_sold", y="avg_price", kind="bar")
chart.set_ylabel("Avocados Sold in Billions")
chart.set_xlabel("Avocado Sizes")

# Create a bar plot of the number of avocados sold by size
# nb_sold_by_size.plot(kind="bar", rot=90)

plt.title("Avocados Sold across Sizes")
# Show the plot
plt.show()
plt.close()
# Out:
#          date          type  year   size  avg_price     nb_sold
# 0  2015-12-27  conventional  2015  small       0.95  9626901.09
# 1  2015-12-20  conventional  2015  small       0.98  8710021.76
# 2  2015-12-13  conventional  2015  small       0.93  9855053.66
# 3  2015-12-06  conventional  2015  small       0.89  9405464.36
# 4  2015-11-29  conventional  2015  small       0.99  8094803.56
# size
# extra_large    1.561752e+08
# large          2.015012e+09
# small          2.054936e+09
# Name: nb_sold, dtype: float64

# %%
# # Import matplotlib.pyplot with alias plt
# import matplotlib.pyplot as plt

# def set_categorical_size(dfsize):
#     if dfsize < 0.8:
#         return (0,"very small")
#     elif 0.8 <= dfsize <= 1.1:
#         return (1,"small")
#     elif 1.1 <= dfsize <= 1.4:
#         return (2,"medium")
#     elif 1.4 <= dfsize <= 1.7:
#         return (3,"large")
#     else:
#         return (4,"very large")

# avocados["cat_size"] = avocados["size"].apply(set_categorical_size)


# # Get the total number of avocados sold of each size
# nb_sold_by_size = avocados.groupby("cat_size")["nb_sold"].sum()
# nb_sold_by_size = nb_sold_by_size.reindex(sorted(nb_sold_by_size.index, key=lambda x: x[0]))
# print(nb_sold_by_size)

# # Extract the second value of each tuple for plotting
# plot_labels = nb_sold_by_size.index.map(lambda x: x[1])

# # Create a bar plot of the number of avocados sold by size
# chart = nb_sold_by_size.plot(kind="bar")

# # Customize the x-axis labels with the extracted second values
# plt.xticks(range(len(plot_labels)), plot_labels, rotation=90)

# chart.set_ylabel("Avocados Sold in Billions")
# chart.set_xlabel("Avocado Sizes")

# plt.title("Avocados Sold across Sizes")
# # Show the plot
# plt.show()
# plt.close()
# Out:
# cat_size
# (0, very small)    8.432675e+07
# (1, small)         2.869382e+09
# (2, medium)        9.966842e+08
# (3, large)         2.622162e+08
# (4, very large)    1.351379e+07
# Name: nb_sold, dtype: float64

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Get the total number of avocados sold on each date
nb_sold_by_date = avocados.groupby("date")["nb_sold"].sum()

# Set rotation angle for x-axis labels
plt.title("Avocados Sold across Time")

# Create a line plot of the number of avocados sold by date
chart = nb_sold_by_date.plot(kind="line", rot=45)
chart.set_ylabel("Avocados Sold in Ten Millions")
chart.set_xlabel("Date")

# Show the plot
plt.show()
plt.close()

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

nb_sold_by_avg_price = avocados.plot(x="nb_sold", y="avg_price", kind="scatter")

plt.title("Number of avocados sold vs. average price")

chart = nb_sold_by_avg_price.plot(kind="scatter", rot=45)

plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt

def showChart(dataFrame, xy, xyDesc, title, kind, xterms, bins): 
    chart = None
    if (kind == "bar"):
        chart = dataFrame.groupby(xy[0])[xy[1]].sum()
        chart = chart.plot(x=xy[0], y=xy[1], kind=kind)
    elif (kind == "hist"):
        chart = dataFrame[dataFrame[xy[0]] == xterms[0]][xy[1]].hist(alpha = 0.7, bins=bins)
        chart = dataFrame[dataFrame[xy[0]] == xterms[1]][xy[1]].hist(alpha = 0.7, bins=bins)
        plt.legend(list(xterms))
    elif (kind == "scatter" or kind == "line"):
        chart = dataFrame.plot(x=xy[0], y=xy[1], kind=kind)
    else:
        print("Chart must be one of the following kinds: ", ['line', 'bar', 'scatter', 'hist', 'barh', 'kde', 'density', 'area', 'box', 'pie', 'hexbin'])
        return None
    chart.set_xlabel(xyDesc[0])
    chart.set_ylabel(xyDesc[1])
    plt.title(title)
    plt.show()
    plt.close()


xy = ("type", "avg_price")
xyDesc = ("Average price", "Number of avocado sold")
title = "Average price vs Number of avocados sold"
kind = "hist"
xterm = ("conventional", "organic")
bins = 20

showChart(avocados, xy, xyDesc, title, kind, xterm, bins)

# %%
def showMissing(dataFrame):
    dataFrame.isna().sum().plot(kind="bar")
    plt.show()

def dropMissing(dataFrame):
    return dataFrame.dropna()

def replaceMissing(dataFrame):
    return dataFrame.fillna(0)

def isAnyMissing(dataFrame):
    return dataFrame.isna().any()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "date" : ['2016-12-25', '2016-12-18', '2016-12-11', '2016-12-04', '2016-11-27', '2016-11-20', '2016-11-13', '2016-11-06', '2016-10-30', '2016-10-23', '2016-10-16', '2016-10-09', '2016-10-02', '2016-09-25', '2016-09-18', '2016-09-11', '2016-09-04', '2016-08-28', '2016-08-21', '2016-08-14', '2016-08-07', '2016-07-31', '2016-07-24', '2016-07-17', '2016-07-10', '2016-07-03', '2016-06-26', '2016-06-19', '2016-06-12', '2016-06-05', '2016-05-29', '2016-05-22', '2016-05-15', '2016-05-08', '2016-05-01', '2016-04-24', '2016-04-17', '2016-04-10', '2016-04-03', '2016-03-27', '2016-03-20', '2016-03-13', '2016-03-06', '2016-02-28', '2016-02-21', '2016-02-14', '2016-02-07', '2016-01-31', '2016-01-24', '2016-01-17', '2016-01-10', '2016-01-03'],
}

avocados_2016 = pd.DataFrame(data)
print(avocados_2016.head())
# Out:
#          date  avg_price   total_sold   small_sold   large_sold    xl_sold  \
# 0  2016-12-25       1.00  30287853.70   9255125.20  10282925.61  541972.42
# 1  2016-12-18       0.96  29583882.61   9394065.91  10339168.20  427872.42
# 2  2016-12-11       0.98  30093540.70   9009996.11          NaN  403047.93
# 3  2016-12-04       1.00  31621221.90  11043350.90   9908982.97  428009.84
# 4  2016-11-27       1.21  22923062.65   7891487.94   7337341.77        NaN
#
#    total_bags_sold  small_bags_sold  large_bags_sold  xl_bags_sold
# 0      10207830.47       7709584.33       2417144.92      81101.22
# 1       9422776.08       6970320.34       2358443.96      94011.78
# 2      10713276.64       8149438.75       2490495.07      73342.82
# 3      10240878.19       7187022.58       2988504.98      65350.63
# 4       7349757.04       5691266.56       1609867.20      48623.28

# %%
showMissing(avocados_2016)

# %%
# Remove rows with missing values
avocados_complete = dropMissing(avocados_2016)

# Check if any columns contain missing values
print(avocados_complete)
# Out:
#           date  avg_price   total_sold   small_sold   large_sold     xl_sold  \
# 0   2016-12-25       1.00  30287853.70   9255125.20  10282925.61   541972.42
# 1   2016-12-18       0.96  29583882.61   9394065.91  10339168.20   427872.42
# 3   2016-12-04       1.00  31621221.90  11043350.90   9908982.97   428009.84
# 6   2016-11-13       1.36  24075126.49   8235135.43   7759608.21   477520.95
# 8   2016-10-30       1.43  21009730.21   7100458.82   6852046.35   453145.26
# 9   2016-10-23       1.34  24753513.95   7579629.06   8104522.26   452383.96
# 11  2016-10-09       1.27  28857581.98   9552502.48   9579338.98   490956.88
# 12  2016-10-02       1.23  29615008.49   9534915.56   9123897.74   490123.01
# 13  2016-09-25       1.22  30305112.89  10548061.13   9255913.78   492604.30
# 14  2016-09-18       1.15  31346091.46  11337829.10   9481313.14   486187.39
# 17  2016-08-28       1.09  33993931.31  12561055.50  10420973.00   563738.54
# ...

# %%
# Remove rows with missing values
avocados_complete = dropMissing(avocados_2016)

# Check if any columns contain missing values
print(isAnyMissing(avocados_complete))
# Out:
# date               False
# avg_price          False
# total_sold         False
# small_sold         False
# large_sold         False
# xl_sold            False
# total_bags_sold    False
# small_bags_sold    False
# large_bags_sold    False
# xl_bags_sold       False
# dtype: bool

# %%
# List the columns with missing values
cols_with_missing = ["small_sold", "large_sold", "xl_sold"]

# Create histograms showing the distributions cols_with_missing
avocados_2016[cols_with_missing].hist()

# Show the plot
plt.show()

# %%
cols_with_missing = ["small_sold", "large_sold", "xl_sold"]
def showMissingColumns(dataFrame, columns):
    dataFrame[columns].hist()

showMissingColumns(avocados_2016, cols_with_missing)
plt.show()

# %%
avocados_filled = replaceMissing(avocados_2016)
showMissingColumns(avocados_filled, cols_with_missing)
plt.show()

# %%
import pandas as pd

# Create a list of dictionaries with new data
avocados_list = [
    {"date": "2019-11-03", "small_sold": 10376832, "large_sold": 7835071},
    {"date": "2019-11-10", "small_sold": 10717154, "large_sold": 8561348},
]

# Convert list into DataFrame
avocados_2019 = pd.DataFrame(avocados_list)

# Print the new DataFrame
print(avocados_2019)
# Out:
#          date small_sold large_sold
# 0  2019-11-03   10376832    7835071
# 1  2019-11-10   10717154    8561348

# %%
import pandas as pd

# Create a dictionary of lists with new data
avocados_dict = {
  "date": ["2019-11-17", "2019-12-01"],
  "small_sold": [10859987,9291631],
  "large_sold": [7674135, 6238096]
}

# Convert list into DataFrame
avocados_2019 = pd.DataFrame(avocados_dict)

# Print the new DataFrame
print(avocados_2019)
# Out:
#          date  small_sold  large_sold
# 0  2019-11-17    10859987     7674135
# 1  2019-12-01     9291631     6238096

# %%
import pandas as pd

def getData(fileName):
     pd.read_csv(fileName)

dataFrame = getData("airline_bumping.csv")

print(dataFrame.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 6
#       3 def getData(fileName):
#       4      pd.read_csv(fileName)
# ----> 6 dataFrame = getData("airline_bumping.csv")
#       8 print(dataFrame.head())
#
# Cell In[31], line 4, in getData(fileName)
#       3 def getData(fileName):
# ----> 4      pd.read_csv(fileName)
#
# ...

# %%
import pandas as pd

# Data to be converted into a DataFrame
data = [
    ["DELTA AIR LINES", 2017, 679, 99796155],
    ["VIRGIN AMERICA", 2017, 165, 60900292],
    ["JETBLUE AIRWAYS", 2017, 1475, 27255038],
    ["UNITED AIRLINES", 2017, 2067, 70030765],
    ["HAWAIIAN AIRLINES", 2017, 92, 84227345],
    ["EXPRESSJET AIRLINES", 2017, 785, 117388126],
    ["SKYWEST AIRLINES", 2017, 917, 245163547],
    ["AMERICAN AIRLINES", 2017, 4517, 98017132],
    ["ALASKA AIRLINES", 2017, 658, 188179249],
    ["SOUTHWEST AIRLINES", 2017, 6678, 11598898810],
    ["FRONTIER AIRLINES", 2017, 540, 1205994311],
    ["SPIRIT AIRLINES", 2017, 1502, 1706964712],
    ["DELTA AIR LINESS", 2016, 912, 97237060],
    ["VIRGIN AMERICA", 2016, 77, 592793814],
    ["JETBLUE AIRWAYS", 2016, 2140, 259908281],
    ["UNITED AIRLINES", 2016, 2874, 644381321],
    ["HAWAIIAN AIRLINES", 2016, 30, 815483817],
    ["EXPRESSJET AIRLINES", 2016, 2541, 161198661],
    ["SKYWEST AIRLINES", 2016, 2177, 225753831],
    ["AMERICAN AIRLINES", 2016, 6598, 993480932],
    ["ALASKA AIRLINES", 2016, 734, 177251972],
    ["SOUTHWEST AIRLINES", 2016, 11907, 112153048],
    ["FRONTIER AIRLINES", 2016, 688, 108950522],
    ["SPIRIT AIRLINES", 2016, 1418, 15234924]
]

# Define the column names
columns = ["airline", "year", "nb_bumped", "total_passengers"]

# Create the DataFrame
airline_bumping = pd.DataFrame(data, columns=columns)

# Display the DataFrame
print(airline_bumping)
# Out:
#                 airline  year  nb_bumped  total_passengers
# 0       DELTA AIR LINES  2017        679          99796155
# 1        VIRGIN AMERICA  2017        165          60900292
# 2       JETBLUE AIRWAYS  2017       1475          27255038
# 3       UNITED AIRLINES  2017       2067          70030765
# 4     HAWAIIAN AIRLINES  2017         92          84227345
# 5   EXPRESSJET AIRLINES  2017        785         117388126
# 6      SKYWEST AIRLINES  2017        917         245163547
# 7     AMERICAN AIRLINES  2017       4517          98017132
# 8       ALASKA AIRLINES  2017        658         188179249
# 9    SOUTHWEST AIRLINES  2017       6678       11598898810
# 10    FRONTIER AIRLINES  2017        540        1205994311
# 11      SPIRIT AIRLINES  2017       1502        1706964712
# 12     DELTA AIR LINESS  2016        912          97237060
# 13       VIRGIN AMERICA  2016         77         592793814
# 14      JETBLUE AIRWAYS  2016       2140         259908281
# ...

# %%
# Get the total number of avocados sold of each size

def getSumGroupYsByX(df, ys, x):
    return df.groupby(x)[ys].sum()

    
ys = ["nb_bumped", "total_passengers"]
x = "airline"
airline_totals = getSumGroupYsByX(airline_bumping, ys, x) 

print(airline_totals)


# airline_totals = airline_bumping.groupby("airline")[["nb_bumped", "total_passengers"]].sum()

# print(airline_totals)
# Out:
#                      nb_bumped  total_passengers
# airline
# ALASKA AIRLINES           1392         365431221
# AMERICAN AIRLINES        11115        1091498064
# DELTA AIR LINES            679          99796155
# DELTA AIR LINESS           912          97237060
# EXPRESSJET AIRLINES       3326         278586787
# FRONTIER AIRLINES         1228        1314944833
# HAWAIIAN AIRLINES          122         899711162
# JETBLUE AIRWAYS           3615         287163319
# SKYWEST AIRLINES          3094         470917378
# SOUTHWEST AIRLINES       18585       11711051858
# SPIRIT AIRLINES           2920        1722199636
# UNITED AIRLINES           4941         714412086
# VIRGIN AMERICA             242         653694106

# %%
# Create new col, bumps_per_10k: no. of bumps per 10k passengers for each airline

# airline_totals["bumps_per_10k"] = airline_totals["nb_bumped"] / airline_totals["total_passengers"] * 10000


def YForEveryNX(df, y, x, n):
    return df[y] / df[x] * n

airline_totals["bumps_per_10k"] = YForEveryNX(airline_totals, "nb_bumped", "total_passengers", 10000)


print(airline_totals["bumps_per_10k"])
# Out:
# airline
# ALASKA AIRLINES        0.038092
# AMERICAN AIRLINES      0.101833
# DELTA AIR LINES        0.068039
# DELTA AIR LINESS       0.093791
# EXPRESSJET AIRLINES    0.119388
# FRONTIER AIRLINES      0.009339
# HAWAIIAN AIRLINES      0.001356
# JETBLUE AIRWAYS        0.125887
# SKYWEST AIRLINES       0.065702
# SOUTHWEST AIRLINES     0.015870
# SPIRIT AIRLINES        0.016955
# UNITED AIRLINES        0.069162
# VIRGIN AMERICA         0.003702
# Name: bumps_per_10k, dtype: float64

# %%
import pandas as pd
airline_totals_sorted = airline_totals.sort_values("bumps_per_10k", ascending = True)
print(airline_totals_sorted)
airline_totals_sorted.to_csv()
# Out:
#                      nb_bumped  total_passengers  bumps_per_10k
# airline
# HAWAIIAN AIRLINES          122         899711162       0.001356
# VIRGIN AMERICA             242         653694106       0.003702
# FRONTIER AIRLINES         1228        1314944833       0.009339
# SOUTHWEST AIRLINES       18585       11711051858       0.015870
# SPIRIT AIRLINES           2920        1722199636       0.016955
# ALASKA AIRLINES           1392         365431221       0.038092
# SKYWEST AIRLINES          3094         470917378       0.065702
# DELTA AIR LINES            679          99796155       0.068039
# UNITED AIRLINES           4941         714412086       0.069162
# DELTA AIR LINESS           912          97237060       0.093791
# AMERICAN AIRLINES        11115        1091498064       0.101833
# EXPRESSJET AIRLINES       3326         278586787       0.119388
# JETBLUE AIRWAYS           3615         287163319       0.125887
# ...
